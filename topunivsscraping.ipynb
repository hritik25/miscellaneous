# %%
import bs4 as bs

# %%
import urllib

# %%
soup = bs.BeautifulSoup('''
<div class="ranking-container">
      <!--mobile version filter-->
      
      <!--End mobile version filter-->
      <div class="filter">
        <div class="row">
          <div class="sel-wrap reg"> <span class="close">X</span>
            <div class="customSelect white-bg left focused" id="select-filter-region" style="z-index: 100;"><select id="filter-region" class="white-bg left jcf-hidden" placeholder="Filter by region" size="4" jcf-size="">
              <option value="">Filter by region</option>
            <option value="6">Africa</option><option value="71">Asia</option><option value="140">Europe</option><option value="213">North America</option><option value="317">Oceania</option><option value="349">Latin America</option></select><span class="jcf-select jcf-unselectable jcf-select-white-bg jcf-select-left jcf-focus"><span class="jcf-select-text"><span class="">Europe</span></span><span class="jcf-select-opener"></span></span><div class="selectValueWrap"><div class="selectedValue"><span><span>Filter by region</span></span><a href="#" class="reset"></a><i class="icon icon-angle-down"></i></div> </div><div class="selectList"><div class="selectListOuterWrap"><div class="selectListInnerWrap"><div class="selectListTop"></div><dl><dd class="itm-0 selected" style="display: none;">Filter by region</dd><dd class="itm-1">Africa</dd><dd class="itm-2">Asia</dd><dd class="itm-3">Europe</dd><dd class="itm-4">North America</dd><dd class="itm-5">Oceania</dd><dd class="itm-6">Latin America</dd></dl><div class="selectListBottom"></div></div></div></div></div>
          </div>
          <div class="sel-wrap cou"> <span class="close hide">X</span>
            <div class="customSelect white-bg left focused" id="select-filter-country" style="z-index: 100;"><select id="filter-country" class="white-bg left jcf-hidden" placeholder="Filter by location" size="4" jcf-size=""><option value="">Filter by location</option><option value="143">Austria</option><option value="146">Belgium</option><option value="151">Czech Republic</option><option value="152">Denmark</option><option value="154">Estonia</option><option value="156">Finland</option><option value="158">France</option><option value="162">Germany</option><option value="166">Greece</option><option value="169">Hungary</option><option value="171">Ireland</option><option value="174">Italy</option><option value="181">Luxembourg</option><option value="187">Netherlands</option><option value="189">Norway</option><option value="190">Poland</option><option value="191">Portugal</option><option value="192">Romania</option><option value="193">Russia</option><option value="196">Serbia</option><option value="197">Slovakia</option><option value="198">Slovenia</option><option value="199">Spain</option><option value="203">Sweden</option><option value="205">Switzerland</option><option value="208">United Kingdom</option></select><span class="jcf-select jcf-unselectable jcf-select-white-bg jcf-select-left jcf-focus"><span class="jcf-select-text"><span class="">Filter by location</span></span><span class="jcf-select-opener"></span></span><div class="selectValueWrap"><div class="selectedValue"><span><span>Filter by location</span></span><a href="#" class="reset"></a><i class="icon icon-angle-down"></i></div> </div><div class="selectList"><div class="selectListOuterWrap"><div class="selectListInnerWrap"><div class="selectListTop"></div><dl style="height: auto; overflow: hidden; padding: 0px; width: 157px;" class="jspScrollable" tabindex="0"><div class="jspContainer" style="width: 157px; height: 300px;"><div class="jspPane" style="padding: 0px; top: 0px; width: 133px;"><dd class="itm-0">Filter by location</dd><dd class="itm-1">Austria</dd><dd class="itm-2">Belgium</dd><dd class="itm-3">Czech Republic</dd><dd class="itm-4">Denmark</dd><dd class="itm-5">Estonia</dd><dd class="itm-6">Finland</dd><dd class="itm-7">France</dd><dd class="itm-8">Germany</dd><dd class="itm-9">Greece</dd><dd class="itm-10">Hungary</dd><dd class="itm-11">Ireland</dd><dd class="itm-12">Italy</dd><dd class="itm-13">Luxembourg</dd><dd class="itm-14">Netherlands</dd><dd class="itm-15">Norway</dd><dd class="itm-16">Poland</dd><dd class="itm-17">Portugal</dd><dd class="itm-18">Romania</dd><dd class="itm-19">Russia</dd><dd class="itm-20">Serbia</dd><dd class="itm-21">Slovakia</dd><dd class="itm-22">Slovenia</dd><dd class="itm-23">Spain</dd><dd class="itm-24">Sweden</dd><dd class="itm-25">Switzerland</dd><dd class="itm-26">United Kingdom</dd></div><div class="jspVerticalBar"><div class="jspCap jspCapTop"></div><div class="jspTrack" style="height: 300px;"><div class="jspDrag" style="height: 95px;"><div class="jspDragTop"></div><div class="jspDragBottom"></div></div></div><div class="jspCap jspCapBottom"></div></div></div></dl><div class="selectListBottom"></div></div></div></div></div>
          </div>
        </div>
      </div>
      <div class="row table-container">
        <table id="ranking-table">
          <thead>
            <tr>
              <th colspan="5"> <span class="n11 brown"> <span class="rank">Rank</span> <span class="uni">University&nbsp;&nbsp;<i class="icon-spinner icon-spin icon-large"></i></span> <span class="country">Location</span>
                                   <span class="match" id="matchunis"><span>Compare</span></span>
                                 <span class="rating">QS Stars <a href="/qs-stars/home" target="_blank" id="qs-stars-help" class="help" title="" data-toggle="tooltip" data-placement="top" data-original-title="QS Stars is distinct from rankings. So far, 150 universities in over 35 countries have been rated in up to 12 categories. Click the QS Stars for detailed results.">?</a></span> </span>
              </th>
            </tr>
            <tr>
              <td class="rank">
                <div class="bright-blue-bg">
                  <div class="customSelect yellow-bg no-reset" id="select-order-values" style="z-index: 100;"><select id="order-values" class="yellow-bg jcf-hidden">
                    <option value="rank">Overall Score</option>
                  <option value="2626498">Academic Reputation</option><option value="2626499">Employer Reputation</option><option value="2626500">Citations per Paper</option><option value="2626501">H-index Citations</option><option value="faculty_value" disabled="disabled">Faculty Value</option></select><span class="jcf-select jcf-unselectable jcf-select-yellow-bg"><span class="jcf-select-text"><span class="">Overall Score</span></span><span class="jcf-select-opener"></span></span><div class="selectValueWrap"><div class="selectedValue"><span><span>Overall Score</span></span><a href="#" class="reset"></a><i class="icon icon-angle-down"></i></div> </div><div class="selectList"><div class="selectListOuterWrap"><div class="selectListInnerWrap"><div class="selectListTop"></div><dl><dd class="itm-0 selected">Overall Score</dd><dd class="itm-1">Academic Reputation</dd><dd class="itm-2">Employer Reputation</dd><dd class="itm-3">Citations per Paper</dd><dd class="itm-4">H-index Citations</dd><dd class="itm-5" style="display: none;">Faculty Value</dd></dl><div class="selectListBottom"></div></div></div></div></div>
                </div>
              </td>
              <td class="uni">
                <div class="blue-bg">
                  <div>
                    <input type="text" id="search-uni" class="gray-bg left" onfocus="this.placeholder = ''" onblur="this.placeholder = 'Search for universities...'" placeholder="Search for universities...">
                    <a href="#" class="search-enter"><span>Search</span></a> </div>
                </div>
              </td>
              <td class="country">
                <div class="bright-blue-bg"></div>
              </td>
                              <td class="match">
                  <div class="bright-blue-bg"></div>
                </td>
                            <td class="rating">
                <div class="yellow-bg">
                  <span class="jcf-checkbox jcf-unchecked"><span></span><input id="check-stars" type="checkbox" style="position: absolute; height: 100%; width: 100%; opacity: 0; margin: 0px;"></span>
                  <label for="check-stars" class="checkbox-label">Show only</label>
                </div>
              </td>
            </tr>
            <tr>
              <td class="rank">
                <div class="bright-blue-bg"></div>
              </td>
              <td class="uni">
                <div class="blue-bg"></div>
              </td>
              <td class="country">
                <div class="bright-blue-bg"></div>
              </td>
                              <td class="match">
                  <div class="blue-bg"></div>
                </td>
                            <td class="rating">
                <div class="yellow-bg"></div>
              </td>
            </tr>
          </thead>
          <tbody><tr class="item hidde odd" id="uni-294654" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of Oxford ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of Oxford ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg" style="width: 90.5%; overflow: hidden;"></span> <span class="ranking">3</span> <span class="result l11" style="left: 85px;">92.5</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-oxford_478_small.jpg" alt="University of Oxford"></span></span> <span class="l12 gray"><a href="/universities/university-oxford#subject">University of Oxford</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="United Kingdom" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/GB.jpg" class="flag" alt="United Kingdom"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-478" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-478"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span></div>
              </td>
            </tr><tr class="item hidde even" id="uni-294561" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of Cambridge ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of Cambridge ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg" style="width: 87.8%; overflow: hidden;"></span> <span class="ranking">6</span> <span class="result l11" style="left: 82px;">89.8</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-cambridge_95_small_0.jpg" alt="University of Cambridge"></span></span> <span class="l12 gray"><a href="/universities/university-cambridge#subject">University of Cambridge</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="United Kingdom" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/GB.jpg" class="flag" alt="United Kingdom"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-95" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-95"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span></div>
              </td>
            </tr><tr class="item hidde odd" id="uni-294432" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is ETH Zurich - Swiss Federal Institute of Technology ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is ETH Zurich - Swiss Federal Institute of Technology ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg" style="width: 84.3%; overflow: hidden;"></span> <span class="ranking">8</span> <span class="result l11" style="left: 78px;">86.3</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/eth-zurich-swiss-federal-institute-of-technology_201_small_0.jpg" alt="ETH Zurich - Swiss Federal Institute of Technology"></span></span> <span class="l12 gray"><a href="/universities/eth-zurich-swiss-federal-institute-technology#subject">ETH Zurich - Swiss Federal Institute of Technology</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Switzerland" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/CH.jpg" class="flag" alt="Switzerland"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-201" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-201"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde even" id="uni-294030" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is Imperial College London ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is Imperial College London ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg" style="width: 81.3%; overflow: hidden;"></span> <span class="ranking">12</span> <span class="result l11" style="left: 74px;">83.3</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/imperial-college-london_356_small.jpg" alt="Imperial College London"></span></span> <span class="l12 gray"><a href="/universities/imperial-college-london#subject">Imperial College London</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="United Kingdom" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/GB.jpg" class="flag" alt="United Kingdom"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-356" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-356"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde odd" id="uni-294481" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is Ecole Polytechnique Fédérale de Lausanne (EPFL) ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is Ecole Polytechnique Fédérale de Lausanne (EPFL) ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg" style="width: 80.6%; overflow: hidden;"></span> <span class="ranking">18</span> <span class="result l11" style="left: 73px;">82.6</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/ecole-polytechnique-fdrale-de-lausanne-epfl_177_small_0.jpg" alt="Ecole Polytechnique Fédérale de Lausanne (EPFL)"></span></span> <span class="l12 gray"><a href="/universities/ecole-polytechnique-f%C3%A9d%C3%A9rale-de-lausanne-epfl#subject">Ecole Polytechnique Fédérale de Lausanne (EPFL)</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Switzerland" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/CH.jpg" class="flag" alt="Switzerland"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-177" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-177"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hid
a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Italy" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/IT.jpg" class="flag" alt="Italy"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-499" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-499"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span><span class="qsstar"></span></div>
              </td>
            </tr><tr class="item hidde odd" id="uni-297479" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is Universität des Saarlandes ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is Universität des Saarlandes ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo empty"></span></span> <span class="l12 gray"><a href="/universities/universit%C3%A4t-des-saarlandes#subject">Universität des Saarlandes</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Germany" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/DE.jpg" class="flag" alt="Germany"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-541" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-541"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde even" id="uni-293992" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is Université Claude Bernard Lyon 1 ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is Université Claude Bernard Lyon 1 ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo empty"></span></span> <span class="l12 gray"><a href="/universities/universit%C3%A9-claude-bernard-lyon-1#subject">Université Claude Bernard Lyon 1</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="France" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/FR.jpg" class="flag" alt="France"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-373" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-373"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde odd" id="uni-294492" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University College Dublin ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University College Dublin ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-college-dublin_166_small_0.jpg" alt="University College Dublin"></span></span> <span class="l12 gray"><a href="/universities/university-college-dublin#subject">University College Dublin</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Ireland" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/IE.jpg" class="flag" alt="Ireland"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-166" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-166"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde even" id="uni-294597" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of Birmingham ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of Birmingham ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-birmingham_59_small_0.jpg" alt="University of Birmingham"></span></span> <span class="l12 gray"><a href="/universities/university-birmingham#subject">University of Birmingham</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="United Kingdom" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/GB.jpg" class="flag" alt="United Kingdom"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-59" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-59"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde odd" id="uni-294587" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of Bristol ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of Bristol ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-bristol_69_small_0.jpg" alt="University of Bristol"></span></span> <span class="l12 gray"><a href="/universities/university-bristol#subject">University of Bristol</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="United Kingdom" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/GB.jpg" class="flag" alt="United Kingdom"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-69" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-69"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde even" id="uni-294516" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of Copenhagen ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of Copenhagen ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-copenhagen_141_small_0.jpg" alt="University of Copenhagen"></span></span> <span class="l12 gray"><a href="/universities/university-copenhagen#subject">University of Copenhagen</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Denmark" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/DK.jpg" class="flag" alt="Denmark"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-141" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-141"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde odd" id="uni-297620" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of Oslo ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of Oslo ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-oslo_473_small.jpg" alt="University of Oslo"></span></span> <span class="l12 gray"><a href="/universities/university-oslo#subject">University of Oslo</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="Norway" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/NO.jpg" class="flag" alt="Norway"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-473" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-473"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr><tr class="item hidde even" id="uni-297128" style="display: table-row;">
              <td class="rank">
                <div class="gray-bg">
                   <div class="social_shares flag_tooltip">
                    <ul class="social_btns">
                      <li class="facebook"><a href="https://www.facebook.com/sharer/sharer.php?u=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-facebook"></i></a></li>
                      <li class="twitter"><a href="https://twitter.com/intent/tweet?text=Where is University of York ranked in the latest QS Subject ranking? http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems%23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-twitter"></i></a></li>
                      <li class="google"><a href="https://plus.google.com/share?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-google-plus"></i></a></li>
                      <li class="linkedin"><a href="https://www.linkedin.com/shareArticle?mini=true&amp;url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems&amp;title=&amp;summary=Where is University of York ranked in the latest QS Subject ranking? http://topuniversities.com/system-strength-rankings/2016 %23QSWUR" class="popup" rel="nofollow" target="_blank"><i class="fa fa-linkedin"></i></a></li>
                      <li class="pinterest"><a href="https://www.pinterest.com/pin/find/?url=http://www.topuniversities.com/university-rankings/university-subject-rankings/2016/computer-science-information-systems" class="popup" rel="nofollow" target="_blank"><i class="fa fa-pinterest-p"></i></a></li>
                    </ul>
                  </div>
                  <div class="bright-blue-bg"> <span class="dark-blue-bg"></span> <span class="ranking smallest">101-150</span> <span class="result l11" style="left: 85px; display: none;">NaN</span> </div>
                </div>
              </td>
              <td class="uni">
                <div class="dark-gray-bg">
                  <div> <span class="logo-wrapper"><span class="logo"><img src="//www.topuniversities.com/sites/default/files/university-of-york_689_small_0.jpg" alt="University of York"></span></span> <span class="l12 gray"><a href="/universities/university-york#subject">University of York</a></span> </div>
                </div>
              </td>
              <td class="country">
                <div class="gray-bg"> <img data-original-title="United Kingdom" data-toggle="tooltip" data-placement="top" src="/sites/all/libraries/flags/GB.jpg" class="flag" alt="United Kingdom"> </div>
              </td>
                              <td class="match">
                  <div class="bright-yellow-bg">
                    <input type="checkbox" id="check-689" class="jquery-once-6-processed">
                    <label class="checkbox-label" for="check-689"></label>
                  </div>
                </td>
                            <td class="rating">
                <div class="gray-bg"></div>
              </td>
            </tr></tbody>
        </table>
      </div>
    </div>''', 'lxml')

# %%
table = soup.table

# %%
tableRows = table.find_all('tr')

# %% [markdown]
# count = 0
# for tr in tableRows:
#     if count < 3:
#         count+=1
#         continue
#     td = tr.find_all('td')
#     row = [str(i.text.encode('utf8')).replace('\n','') for i in td]
#     ranknrating = [s for s in row[0].split() if s.isdigit() or s == '51-100']
#     row[0] = ranknrating[0]
#     print row[0:2]

# %%
count = 0
for tr in tableRows:
    if count < 3:
        count+=1
        continue
    td = tr.find_all('td')
    row = [str(i.text.encode('utf8')).replace('\n','') for i in td]
    ranknrating = [s for s in row[0].split() if (s.isdigit() or '-' in s) ]
    row[0] = ranknrating[0]
    print row[0:2]
# Out:
# ['3', '  University of Oxford ']
# ['6', '  University of Cambridge ']
# ['8', '  ETH Zurich - Swiss Federal Institute of Technology ']
# ['12', '  Imperial College London ']
# ['18', '  Ecole Polytechnique F\xc3\xa9d\xc3\xa9rale de Lausanne (EPFL) ']
# ['20', '  The University of Edinburgh ']
# ['33', '  UCL (University College London) ']
# ['36', '  Technical University of Munich ']
# ['43', '  Politecnico di Milano ']
# ['51-100', '  Delft University of Technology ']
# ['51-100', '  Ecole normale sup\xc3\xa9rieure, Paris ']
# ['51-100', '  Ecole Polytechnique ']
# ['51-100', '  Humboldt-Universit\xc3\xa4t zu Berlin ']
# ['51-100', '  KU Leuven ']
# ['51-100', "  King's College London "]
# ['51-100', '  KIT, Karlsruhe Institute of Technology ']
# ['51-100', '  KTH Royal Institute of Technology  ']
# ['51-100', '  Lomonosov Moscow State University  ']
# ['51-100', '  London School of Economics and Political Science (LSE) ']
# ...

# %%
import csv
with open('topunivseurope.csv', 'wb') as csvfile:
    writer = csv.writer(csvfile, delimiter=',')
    writer.writerow(['Rank','Name of University'])
    count = 0
    for tr in tableRows:
        if count < 3:
            count+=1
            continue
        td = tr.find_all('td')
        row = [str(i.text.encode('utf8')).replace('\n','') for i in td]
        ranknrating = [s for s in row[0].split() if (s.isdigit() or '-' in s) ]
        row[0] = ranknrating[0]
        writer.writerow(row[0:2])
